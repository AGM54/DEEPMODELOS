# %%
# !pip -q install transformers einops accelerate

# %%
from transformers import AutoTokenizer
import transformers

# %%
model = "TinyLlama/TinyLlama_v1.1"
# model = "Doctor-Shotgun/TinyLlama-1.1B-32k-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/4.40G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/129 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
prompt = "Explain to me the difference between nuclear fission and fusion."
response = pipeline(
    prompt,
    max_length=500,
    truncation = True,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
print(response[0]['generated_text'])
# Out:
# Explain to me the difference between nuclear fission and fusion.
# What's the difference between nuclear fission and fusion?
# The difference is that fission, which is also known as splitting, releases energy, whereas fusion produces no heat.
# In Fission, the atoms are split in the nucleus and release energy. In fusion, the nuclei of hydrogen atoms combine to form Helium atoms, which is a type of stable atom.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline


model = "Doctor-Shotgun/TinyLlama-1.1B-32k-Instruct"


tokenizer = AutoTokenizer.from_pretrained(model)
model = AutoModelForCausalLM.from_pretrained(model)


text_generation_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)


prompt = "Explain to me the difference between nuclear fission and fusion."


response = text_generation_pipeline(
    prompt,
    max_length=500,
    truncation=True,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)


print(response[0]['generated_text'])
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Explain to me the difference between nuclear fission and fusion. 1. Nuclear Fission: The process through which an atom splits apart into smaller atoms. Fusion: The reverse process of nuclear fission where atoms are joined back together. What is the difference between nuclear fission and fusion?. 24 Jun - 3 min - Uploaded by Nuclear Physics and Nuclear Energy. The difference between nuclear fusion, nuclear fission, and nuclear fusion.
# Nuclear fission is the process through which an atom splits apart and the resulting. 5 Nov - 27 min - Uploaded by Nuclear Physics and Nuclear Energy. The difference between nuclear fission, nuclear. 5 Nov - 11 min - Uploaded by Nuclear Physics and Nuclear Education Nuclear Fission vs.

# %% [markdown]
# OTRO MODELO

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch

model = "EleutherAI/gpt-neo-1.3B"


tokenizer = AutoTokenizer.from_pretrained(model)
model = AutoModelForCausalLM.from_pretrained(model)

device = 0 if torch.cuda.is_available() else -1

text_generation_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device=device
)

prompt = "Explain to me the difference between nuclear fission and fusion."


response = text_generation_pipeline(
    prompt,
    max_length=300,
    truncation=True,
    do_sample=True,
    top_k=50,
    num_return_sequences=1
)

print(response[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Explain to me the difference between nuclear fission and fusion. In your words nuclear fission occurs when a neutron (a proton in this case) is released (the fission of an atom) and a nuclear chain reaction occurs which adds a neutron to the system and this neutron then decays leaving a neutron which then decays into another neutron and a proton. These neutrons then repeat the cycle until there are no neutrons left to add to the system.
#
# In your words nuclear fusion occurs when two different species of atoms are combined to create a new element. This new element is usually a compound of the two or more atomic species.
#
# In your description nuclear fusion doesn't really exist. Just thinking about it is enough to get me to start asking questions. It's very interesting and I'm thinking that most people don't understand it very well but you seem to. If you can break it down a little further on a level of "elementary particles" perhaps I'll understand it a little better.
#
# Why are you so specific about a neutron? You can't really get neutrons, unless they're radioactive, and that would make for a lot of different nuclear reactions. I mean, a proton, a neutron etc. Are you saying you think of a neutron in this way?
#
# A proton and a neutron are simply two different forms of the same atom. If we can break it down, to elementary particles, the atomic nucleus is made
